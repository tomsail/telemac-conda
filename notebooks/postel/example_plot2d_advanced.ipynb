# %% [markdown]
# # Advanced example of plot2d
#
# Functions are defined in /scripts/python3/postel/plot2d.py

# %%
from os import environ, path
import matplotlib.pyplot as plt
import numpy as np
from data_manip.extraction.telemac_file import TelemacFile
from postel.plot2d import *

# %% [markdown]
# ## Plot the 2d mesh with liquid boundaries numbering (same as the one in telemac)

# %%
# File we are going to use
file_name = path.join(environ['HOMETEL'], 'examples', 'telemac2d', 'confluence', 'f2d_confluence.slf')
bnd_file = path.join(environ['HOMETEL'], 'examples', 'telemac2d', 'confluence', 'geo_confluence.cli')

# Initalisaing Telemac file reader
res = TelemacFile(file_name, bnd_file=bnd_file)

# Plot definition
fig, ax = plt.subplots(1, 1, figsize=(14, 5))
ax.set_aspect('equal')
  
# Get liquid boundary info
liq_bnd_info = res.get_liq_bnd_info()

# Plot mesh
plot2d_annotate_liq_bnd(ax, res.tri, liq_bnd_info, markersize=1.5, marker='o')
plot2d_triangle_mesh(ax, res.tri, x_label='X (m)', y_label='Y (m)', color='k', linewidth=0.1)

ax.set_title('2D mesh (%d triangles, %d nodes)' % (len(res.tri.triangles), len(res.tri.x)))
plt.show()
plt.close(fig)

# %% [markdown]
# ## Plot the 2d mesh with boundary conditions

# %%
# File we are going to use
file_ini = path.join(environ['HOMETEL'], 'examples', 'telemac2d', 'malpasset', 'geo_malpasset-small.slf')
file_name = path.join(environ['HOMETEL'], 'examples', 'telemac2d', 'malpasset', 'f2d_malpasset-kin1.slf')
bnd_file = path.join(environ['HOMETEL'], 'examples', 'telemac2d', 'malpasset', 'geo_malpasset-small.cli')

# Initalisaing Telemac file 
res = TelemacFile(file_name, bnd_file=bnd_file)

# Getting values
H = res.get_data_value('WATER DEPTH', -1)
Ux = res.get_data_value('VELOCITY U', -1)
Uy = res.get_data_value('VELOCITY V', -1)

# figure definition
fig, ax = plt.subplots(1, 1, figsize=(14, 8))
ax.set_aspect('equal')

# Get boundary condition type
bnd_info = res.get_bnd_info()

# Plot mesh
plot2d_annotate_bnd(ax, res.tri, bnd_info, markersize=1.5, marker='o')
plot2d_triangle_mesh(ax, res.tri, x_label='X (m)', y_label='Y (m)', color='k', linewidth=0.1)

ax.set_title('2D mesh (%d triangles, %d nodes)' % (len(res.tri.triangles), len(res.tri.x)))
plt.show()
plt.close(fig)
del res

# %% [markdown]
# ## Plot scalar map without dry zones

# %%
# Initalisaing Telemac file 
res = TelemacFile(file_name, bnd_file=bnd_file)
H = res.get_data_value('WATER DEPTH', -1)

# Initialising matplotlib figure
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
ax.set_aspect('equal')

# Plotting mesh
plot2d_triangle_mesh(ax, res.tri, color='k', linewidth=0.1)

# Define mask to hide dry zones in scalar 2d map
mask = mask_triangles(res.tri, H, relation='leq', threshold=0.01)
res.tri.set_mask(mask)

plot2d_scalar_map(fig, ax, res.tri, H, data_name='water depth (m)', vmax=10)

# Defining labels
ax.set_title('Malpasset, result at time: %d s'%res.times[0])
ax.set_xlabel('X-coordonate (m)')
ax.set_ylabel('Y-coordonate (m)')

# Showing the plot
plt.show()
plt.close(fig)

# Reset mask
res.tri.set_mask(None)
del res

# %% [markdown]
# ## Plot scalar fileld contours without dry zones

# %%
# Initalisaing Telemac file 
res = TelemacFile(file_name, bnd_file=bnd_file)
H = res.get_data_value('WATER DEPTH', -1)

# Initialising matplotlib figure
fig, ax = plt.subplots(1, 1, figsize=(20, 10))
ax.set_aspect('equal')

# Plotting mesh
plot2d_triangle_mesh(ax, res.tri, color='k', linewidth=0.1)

# Plot scalar filled contours with min value corresponding to the dry zone
plot2d_scalar_filled_contour(fig, ax, res.tri, H, data_name='water depth (m)', vmin=0.01, vmax=10)

# Defining labels
ax.set_title('Malpasset, result at time: %d s'%res.times[0])
ax.set_xlabel('X-coordonate (m)')
ax.set_ylabel('Y-coordonate (m)')

# Showing the plot
plt.show()
plt.close(fig)
del res

# %% [markdown]
# ## Zoom on a specific location and conserve equal aspect ratio

# %%
# Initalisaing Telemac file
res = TelemacFile(file_name, bnd_file=bnd_file)
H = res.get_data_value('WATER DEPTH', -1)

# figure definition
fig, ax = plt.subplots(1, 1, figsize=(20, 5))

plot2d_triangle_mesh(ax, res.tri, color='k', linewidth=0.1)
plot2d_scalar_filled_contour(fig, ax, res.tri, H, data_name='water depth (m)', vmin=0.01, vmax=10)

ax.set_title('Malpasset, result at time: %d s'%res.times[0])
ax.set_xlabel('X-coordonate (m)')
ax.set_ylabel('Y-coordonate (m)')

# Setting y limits
ylim = [1500, 6000]
ax.set_ylim(ylim[0], ylim[1])
ax.set_aspect('equal')

# Showing the plot
plt.show()
plt.close(fig)
del res

# %% [markdown]
# ## Adjust colorbar properties

# %%
# Initalisaing Telemac file
res0 = TelemacFile(file_ini, bnd_file=bnd_file)
H0 = res0.get_data_value('WATER DEPTH', 0)

res = TelemacFile(file_name, bnd_file=bnd_file)
H1 = res.get_data_value('WATER DEPTH', -1)

# figure definition
fig, axes = plt.subplots(2, 1, figsize=(20, 10))

# custom cbar dict:
cbar_deco = {
    'orientation': "vertical",
    'fraction': 0.2,
    'pad': 0.05,
    'shrink': 0.75,
    'aspect':30.0,
    'anchor': (0.0, 0.5),
    'panchor': (1.0, 0.5),
    'extend': "neither",
    'extendfrac': None,
    'extendrect': False,
    'spacing': 'uniform',
    'ticks':  [0.01, 11, 22, 33, 44, 55],
    'format': '%.0f',
    'drawedges': True,
    }

# plot2d with custom cbar dict and with a shared axis:
plot2d_scalar_filled_contour(fig, axes[0], res.tri, H0, data_name='water depth (m)',
                             vmin=0.01, vmax=55, colorbar=False)

plot2d_scalar_filled_contour(fig, axes[1], res.tri, H1, data_name='water depth (m)',
                             vmin=0.01, vmax=55, cbar_ax=axes, cbar_properties=cbar_deco)

for ax in axes:
    plot2d_triangle_mesh(ax, res.tri, color='k', linewidth=0.1)
    ax.set_xlabel('X-coordonate (m)')
    ax.set_ylabel('Y-coordonate (m)')

    # Setting y limits
    ylim = [1500, 6000]
    ax.set_ylim(ylim[0], ylim[1])
    ax.set_aspect('equal')


# Showing the plot
plt.show()
plt.close(fig)
del res

# %% [markdown]
# ## Plot scalar map and streamlines with mesh overlay only in dry zones

# %%
# Initalisaing Telemac file
res = TelemacFile(file_name, bnd_file=bnd_file)
H = res.get_data_value('WATER DEPTH', -1)
Ux = res.get_data_value('VELOCITY U', -1)
Uy = res.get_data_value('VELOCITY V', -1)

# Initialising matplotlib figure
fig, ax = plt.subplots(1, 1, figsize=(20, 12))

# Define wet and dry zones mask
mask_wet = mask_triangles(res.tri, H, relation='geq', threshold=0.01)
mask_dry = mask_triangles(res.tri, H, relation='leq', threshold=0.01)

# Plotting mesh only on dry zones
res.tri.set_mask(mask_wet)
plot2d_triangle_mesh(ax, res.tri, color='sienna', linewidth=0.2)

# Plotting scalar map only on wet zones
res.tri.set_mask(mask_dry)
plot2d_scalar_map(fig, ax, res.tri, H, data_name='water depth (m)', vmin=0, vmax=10, nv=16)

# Setting x, y limits
xlim = [3000, 8000]
ylim = [2500, 5500]

# Plotting streamlines 
plot2d_streamlines(fig, ax, res.tri, Ux, Uy, 
                   grid_resolution=[100, 100],
                   grid_xlim=xlim, grid_ylim=ylim,
                   data_name='velocity streamlines', density=10, color='k')

# Defining plot limits
ax.set_xlim(xlim[0], xlim[1])
ax.set_ylim(ylim[0], ylim[1])

# Defining labels
ax.set_title('Malpasset, result at time: %d s'%res.times[0])
ax.set_xlabel('X-coordonate (m)')
ax.set_ylabel('Y-coordonate (m)')
ax.set_aspect('equal')

# Showing the plot
plt.show()
plt.close(fig)
del res

# %% [markdown]
# ## Plot scalar map on triangulation and vectors on grid with mesh overlay only in dry zones

# %%
# Initalisaing Telemac file
res = TelemacFile(file_name, bnd_file=bnd_file)
H = res.get_data_value('WATER DEPTH', -1)
Ux = res.get_data_value('VELOCITY U', -1)
Uy = res.get_data_value('VELOCITY V', -1)

# Initialising matplotlib figure
fig, ax = plt.subplots(1, 1, figsize=(20, 12))

# Define wet and dry zones mask
mask_wet = mask_triangles(res.tri, H, relation='geq', threshold=0.01)
mask_dry = mask_triangles(res.tri, H, relation='leq', threshold=0.01)

# Plotting mesh only on dry zones
res.tri.set_mask(mask_wet)
plot2d_triangle_mesh(ax, res.tri, color='sienna', linewidth=0.2)

# Plotting scalar map only on wet zones
res.tri.set_mask(mask_dry)
plot2d_scalar_map(fig, ax, res.tri, H, data_name='water depth (m)', vmin=0, vmax=10, nv=16)

# Setting x, y limits
xlim = [3000, 8000]
ylim = [2000, 6000]

# Plotting vectors 
plot2d_vectors(fig, ax, res.tri, Ux, Uy, data_name='velocity',\
               normalize=False,
               scale=200,
               grid_resolution=[100, 80],
               grid_xlim=xlim, grid_ylim=ylim,
               color='k', pivot='mid',
               width=0.001, headwidth=3., headlength=4.)

# Defining plot limits
ax.set_xlim(xlim[0], xlim[1])
ax.set_ylim(ylim[0], ylim[1])

# Defining labels
ax.set_title('Malpasset, result at time: %d s'%res.times[0])
ax.set_xlabel('X-coordonate (m)')
ax.set_ylabel('Y-coordonate (m)')
ax.set_aspect('equal')

# Showing the plot
plt.show()

# %% [markdown]
# ## Rotate results

# %%
# Initialising matplotlib figure
fig, ax = plt.subplots(1, 1, figsize=(10, 20))
ax.set_aspect('equal')

# Rotate mesh and vector field
res.tri.x, res.tri.y = rotate(res.tri.x, res.tri.y, angle=75)
Ux, Uy = rotate(Ux, Uy, angle=75)

# Define wet and dry zones mask
mask_wet = mask_triangles(res.tri, H, relation='geq', threshold=0.01)
mask_dry = mask_triangles(res.tri, H, relation='leq', threshold=0.01)

# Plotting mesh only on dry zones
res.tri.set_mask(mask_wet)
plot2d_triangle_mesh(ax, res.tri, color='sienna', linewidth=0.2)

# Plotting scalar map only on wet zones
res.tri.set_mask(mask_dry)
plot2d_scalar_map(fig, ax, res.tri, H, data_name='water depth (m)', vmin=0, vmax=10, nv=16, colorbar=False)

# Setting x, y limits and center of figure
xlim = [5000, 6000]
ylim = [-6000, -3500]

# Plotting vectors
plot2d_vectors(fig, ax, res.tri, Ux, Uy, data_name='velocity',\
               normalize=False,
               scale=200,
               color='k', pivot='mid',
               width=0.001, headwidth=3., headlength=4.)

# Defining plot limits
ax.set_xlim(xlim[0], xlim[1])
ax.set_ylim(ylim[0], ylim[1])

# Defining custom colorbar:
img = ax.collections[0]
v = np.linspace(0, 20, 10, endpoint=True)
cbar = fig.colorbar(img, ax=ax, ticks=v, format='%.0f',
                    fraction=0.15, aspect=20, shrink=.75, pad=0.05,
                    orientation='horizontal', extend='both')
cbar.set_label('Water depth (m)')

# Defining labels
ax.set_title('Malpasset, result at time: %d s'%res.times[0])
ax.set_xlabel("X'-coordonate (m)")
ax.set_ylabel("Y'-coordonate (m)")

# Showing the plot
plt.show()

# Closing file
del res
